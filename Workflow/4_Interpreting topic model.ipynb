# %%
import pickle
import pandas as pd
import numpy as np
from pprint import pprint

# %%
corpus = pickle.load(open('corpus','rb'))           #list of text/doc
id2word = pickle.load(open('id2word', 'rb'))        #dictionary
model = pickle.load(open('optimal_lda_model', 'rb'))#LDA model
# Out:
# /Users/crystalhuang/anaconda3/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
#reading in original df
df=pd.read_csv('processed_clean_df.csv')
df.shape
# Out:
# (258961, 11)

# %%
## Tokenize words and further clean-up text
from gensim.utils import simple_preprocess

def sent_to_words(sentences):
    for sentence in sentences:
        yield(simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data = df.abstract_processed.values.tolist()
data_words = list(sent_to_words(data))

# %% [markdown]
# # Finding the dominant topic in each document

# %%
def format_topics_sentences(ldamodel=model, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
#this will take awhile
df_topic_sents_keywords = format_topics_sentences(ldamodel=model, corpus=corpus, texts=data)

# %%
df_topic_sents_keywords.head()
# Out:
#    Dominant_Topic  Perc_Contribution  \
# 0            15.0             0.3562
# 1            17.0             0.3029
# 2            22.0             0.3984
# 3            22.0             0.3532
# 4             6.0             0.5648
#
#                                       Topic_Keywords  \
# 0  risk, procedure, mask, surgical, use, surgery,...
# 1  system, use, technology, application, base, di...
# 2  care, patient, health, pandemic, service, heal...
# 3  care, patient, health, pandemic, service, heal...
# 4  health, pandemic, disease, public, country, wo...
#
#                                                    0
# 0  since 1988 when world health organization (who...
# 1  the paper is focused on analysis of compliance...
# 2  purpose due to covid 19 pandemic the treatment...
# 3  backgroundwith no vaccine or treatment for sar...
# 4  human history is observing a very horrible and...

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0            15.0              0.3562
# 1            1            17.0              0.3029
# 2            2            22.0              0.3984
# 3            3            22.0              0.3532
# 4            4             6.0              0.5648
# 5            5            14.0              0.2650
# 6            6            12.0              0.4439
# 7            7             3.0              0.4693
# 8            8            12.0              0.8390
# 9            9            20.0              0.5970
#
#                                             Keywords  \
# 0  risk, procedure, mask, surgical, use, surgery,...
# 1  system, use, technology, application, base, di...
# 2  care, patient, health, pandemic, service, heal...
# 3  care, patient, health, pandemic, service, heal...
# 4  health, pandemic, disease, public, country, wo...
# 5  study, treatment, review, use, trial, clinical...
# 6  cell, response, expression, immune, induce, me...
# 7  cov, sar, infection, virus, respiratory, viral...
# 8  cell, response, expression, immune, induce, me...
# 9  research, development, paper, article, new, pr...
#
#                                                 Text
# 0  since 1988 when world health organization (who...
# 1  the paper is focused on analysis of compliance...
# 2  purpose due to covid 19 pandemic the treatment...
# 3  backgroundwith no vaccine or treatment for sar...
# 4  human history is observing a very horrible and...
# 5  inhaled therapy is the cornerstone in the mana...
# 6  fibrosis is driven by a misdirected cell respo...
# 7  a subset of patients with sars-cov-2 infection...
# 8  the reproductive tract in avian females is sen...
# 9  this article discusses the impact of the covid...

# %%
df_dominant_topic.shape
# Out:
# (258961, 5)

# %%
df_dominant_topic['Title'] = df.title
df_dominant_topic['url'] = df.url

# %%
df_dominant_topic.head()
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0            15.0              0.3562
# 1            1            17.0              0.3029
# 2            2            22.0              0.3984
# 3            3            22.0              0.3532
# 4            4             6.0              0.5648
#
#                                             Keywords  \
# 0  risk, procedure, mask, surgical, use, surgery,...
# 1  system, use, technology, application, base, di...
# 2  care, patient, health, pandemic, service, heal...
# 3  care, patient, health, pandemic, service, heal...
# 4  health, pandemic, disease, public, country, wo...
#
#                                                 Text  \
# 0  since 1988 when world health organization (who...
# 1  the paper is focused on analysis of compliance...
# 2  purpose due to covid 19 pandemic the treatment...
# 3  backgroundwith no vaccine or treatment for sar...
# 4  human history is observing a very horrible and...
#
#                                                Title  \
# 0  Progress Toward Poliovirus Containment Impleme...
# 1   Anti)social Monitoring: Law and (or) Expediency?
# 2  Running of high patient volume radiation oncol...
# 3  Rapid Development of a De Novo Convalescent Pl...
# 4                      COVID – 19 and gravid mothers
#
#                                                  url
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  http://medrxiv.org/cgi/content/short/2020.10.2...
# 4                                                NaN

# %%
df_dominant_topic.to_csv("df_dominant_topic.csv", index=False)

# %% [markdown]
# # Find the most representative document for each topic

# %%
# Group top 5 doc under each topic
sent_topics_sorted_df = pd.DataFrame()

sent_topics_outdf_grpd = df_dominant_topic.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorted_df = pd.concat([sent_topics_sorted_df, 
                                             grp.sort_values(['Topic_Perc_Contrib'], ascending=[0]).head(5)], 
                                            axis=0)

# Reset Index    
sent_topics_sorted_df.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorted_df.columns = ['Document_No', 'Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text", "Title", "url"]

# Show
sent_topics_sorted_df.head(10)
# Out:
#    Document_No  Topic_Num  Topic_Perc_Contrib  \
# 0          863        0.0              0.8339
# 1          231        0.0              0.7932
# 2       114868        0.0              0.7640
# 3        35771        0.0              0.7640
# 4        95651        0.0              0.7266
# 5        27064        1.0              0.9311
# 6       142793        1.0              0.9236
# 7        60134        1.0              0.9001
# 8       181787        1.0              0.8929
# 9       217422        1.0              0.8929
#
#                                             Keywords  \
# 0  student, education, learning, online, school, ...
# 1  student, education, learning, online, school, ...
# 2  student, education, learning, online, school, ...
# 3  student, education, learning, online, school, ...
# 4  student, education, learning, online, school, ...
# 5  increase, lockdown, period, number, country, c...
# 6  increase, lockdown, period, number, country, c...
# 7  increase, lockdown, period, number, country, c...
# 8  increase, lockdown, period, number, country, c...
# 9  increase, lockdown, period, number, country, c...
#
#                                                 Text  \
# 0  when the covid-19 pandemic closed her universi...
# 1  the east london gp and honorary clinical senio...
# 2  during the covid-19 pandemic universities arou...
# 3  during the covid-19 pandemic universities arou...
# 4  remote learning has been thrust into the spotl...
# 5  we investigate for the first time the empirica...
# 6  in this study we characterize the impacts of c...
# 7  in the present study pollutants levels from 24...
# 8  ron fricker assesses the impact of the pandemi...
# 9  ron fricker assesses the impact of the pandemi...
#
#                                                Title  \
# 0  First Person: The pandemic’s silver lining: Re...
# 1  Supporting GPs to tackle domestic violence: fi...
# 2  Perspective from a Teaching and Learning Cente...
# 3  Perspective from a Teaching and Learning Cente...
# 4  Promote an unexpected online experience throug...
# 5  The Macroeconomic Determinants of COVID19 Mort...
# 6  Spatial and temporal variations of air polluti...
# 7  Covid-19 and air pollution in indian cities: W...
# 8                             Covid-19: One year on…
# 9                             Covid‐19: One year on…
#
#                                                  url
# 0                                                NaN
# 1                                                NaN
# 2  https://doi.org/10.5688/ajpe8142; https://www....
# 3                                                NaN
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 5                                                NaN
# 6  https://www.ncbi.nlm.nih.gov/pubmed/33024128/;...
# 7                                                NaN
# 8                                                NaN
# 9  https://www.ncbi.nlm.nih.gov/pubmed/33821159/;...

# %%
sent_topics_sorted_df[['Topic_Num','Keywords', 'Title']]
# Out:
#     Topic_Num                                           Keywords  \
# 0         0.0  student, education, learning, online, school, ...
# 1         1.0  increase, lockdown, period, number, country, c...
# 2         2.0  protein, drug, target, vaccine, host, interact...
# 3         3.0  cov, sar, infection, virus, respiratory, viral...
# 4         4.0  patient, case, symptom, day, ct, follow, clini...
# 5         5.0  child, health, mental, anxiety, psychological,...
# 6         6.0  health, pandemic, disease, public, country, wo...
# 7         7.0  ace, lung, receptor, tissue, entry, angiotensi...
# 8         8.0  policy, economic, pandemic, social, crisis, im...
# 9         9.0  food, high, energy, temperature, surface, prod...
# 10       10.0  test, positive, testing, sample, result, detec...
# 11       11.0  gene, sequence, genetic, genome, mutation, str...
# 12       12.0  cell, response, expression, immune, induce, me...
# 13       13.0  group, high, risk, age, patient, mortality, co...
# 14       14.0  study, treatment, review, use, trial, clinical...
# 15       15.0  risk, procedure, mask, surgical, use, surgery,...
# 16       16.0  case, infection, epidemic, china, death, repor...
# 17       17.0  system, use, technology, application, base, di...
# 18       18.0  cancer, patient, treatment, tumor, survival, t...
# 19       19.0  use, survey, participant, result, social, repo...
# 20       20.0  research, development, paper, article, new, pr...
# 21       21.0  chinese, epitope, medicine, traditional, diffu...
# 22       22.0  care, patient, health, pandemic, service, heal...
# 23       23.0  concentration, effect, use, dose, increase, hi...
# 24       24.0  network, work, social, interaction, relationsh...
# 25       25.0  patient, disease, severe, clinical, respirator...
# 26       26.0  model, use, datum, method, base, result, analy...
# 27       27.0  patient, hospital, care, unit, icu, admission,...
#
#                                                 Title
# 0   First Person: The pandemic’s silver lining: Re...
# 1   The Macroeconomic Determinants of COVID19 Mort...
# 2   In Silico Identification of a Potent Arsenic B...
# 3   Evaluation of cutaneous symptoms in children i...
# 4   Olfactory disorder in patients infected with S...
# 5   The immediate mental health impacts of the COV...
# 6   Strategies for prevention and control of COVID...
# 7   [2019 novel coronavirus, angiotensin convertin...
# 8   An ayuda to the least advantaged: providing a ...
# 9   Highly regioselective 1,3-dipolar cycloadditio...
# 10  The Dynamic Change of Antibody Index Against C...
# 11  Following the imperative of food security. How...
# 12  New (re)Purpose for an old drug: purinergic re...
# 13  Drug-Drug Interactions and Prescription Approp...
# 14  Hydroxychloroquine Safety: A Meta-Analysis of ...
# 15    Erratum regarding previously published articles
# 16  A descriptive study of the current situation o...
# 17                   Microsoft Digital Defense Report
# 18  Invasive ductal breast carcinoma metastasis to...
# 19  Female gender and knowing a person positive fo...
# 20                    Summary and Policy Implications
# 21  Testagem de rastreio e busca ativa de infectad...
# 22     Family-centered care with visitor limitations.
# 23  The effects of teflubenzuron on mortality, phy...
# 24  Some Notes on Spaces of Ideals and Computable ...
# 25  Efficacy and safety of tocilizumab in critical...
# 26  An Approach to the Selection of a Time Series ...
# 27  Stroke in the Time of COVID-19 Experience in T...

# %% [markdown]
# # Topic distribution across documents

# %%
# Number of Documents for Each Topic
topic_counts = df_dominant_topic['Dominant_Topic'].value_counts()

# Percentage of Documents for Each Topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4)

# Topic Number and Keywords
topic_num_keywords = df_dominant_topic[['Dominant_Topic', 'Keywords']]

# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis=1)

# Change Column names
df_dominant_topics.columns = ['Dominant_Topic', 'Topic_Keywords', 'Num_Documents', 'Perc_Documents']

# Show
df_dominant_topics.head()
# Out:
#      Dominant_Topic                                     Topic_Keywords  \
# 0.0            15.0  risk, procedure, mask, surgical, use, surgery,...
# 1.0            17.0  system, use, technology, application, base, di...
# 2.0            22.0  care, patient, health, pandemic, service, heal...
# 3.0            22.0  care, patient, health, pandemic, service, heal...
# 4.0             6.0  health, pandemic, disease, public, country, wo...
#
#      Num_Documents  Perc_Documents
# 0.0         4262.0          0.0165
# 1.0        11065.0          0.0427
# 2.0        11384.0          0.0440
# 3.0        16376.0          0.0632
# 4.0        13957.0          0.0539
